# %%
from Data_procesing import data_process
print('Hello you')
file_path = 'C:/Users/Ghassen/Documents/Projects/Immobilier/1_Project/Data_assets/Brut/valeursfoncieres-2019.txt'
df = data_process.read_clean_process(file_path)
print(len(df))
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-a457282c1c00> in <module>
# ----> 1 from Data_procesing import data_process
#       2 print('Hello you')
#       3 file_path = 'C:/Users/Ghassen/Documents/Projects/Immobilier/1_Project/Data_assets/Brut/valeursfoncieres-2019.txt'
#       4 df = data_process.read_clean_process(file_path)
#       5 print(len(df))
#
# ModuleNotFoundError: No module named 'Data_procesing'

# %%
from concat_df import concat_df as cd
files_root_path = 'C:/Users/Ghassen/Documents/Projects/Immobilier/1_Project/Data_assets/Brut/valeursfoncieres-'
list_paths = []
extension = '.txt'
for year in range(2015, 2020):
    list_paths.append(files_root_path + str(year) + extension)
df = cd.concatenate(list_paths)
print(len(df))
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-f965aa2b186c> in <module>
# ----> 1 from concat_df import concat_df as cd
#       2 files_root_path = 'C:/Users/Ghassen/Documents/Projects/Immobilier/1_Project/Data_assets/Brut/valeursfoncieres-'
#       3 list_paths = []
#       4 extension = '.txt'
#       5 for year in range(2015, 2020):
#
# c:\Users\Ghassen\Documents\Projects\Immobilier\1_Project\Code\concat_df.py in <module>
#       1 import pandas as pd
# ----> 2 from Data_procesing import data_process as dp
#       3
#       4 def concatenate (df_list_path):
#       5     df = pd.DataFrame()
#
# ModuleNotFoundError: No module named 'Data_procesing'

# %%
import pandas as pd
import time

start_time = time.time()
file_path = 'C:/Users/Ghassen/Documents/Projects/Immobilier/1_Project/Data_assets/Processed/destination_cleaned.csv'
df = pd.read_csv(file_path)
print(len(df))
print((time.time()-start_time), s)
df.head()
# Out:
# C:\Users\Ghassen\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (10,11,13,15,17,19,27) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 14880473
# 76.12458682060242
#    Unnamed: 0  No_disposition Date_mutation Nature_mutation  Valeur_fonciere  \
# 0           0               2    2015-05-01           Vente            120.0
# 1           1               1    2015-09-01           Vente          12400.0
# 2           2               2    2015-05-01           Vente            110.0
# 3           3               2    2015-07-01           Vente            180.0
# 4           4               1    2015-12-01           Vente          95000.0
#
#    No_voie Type_de_voie               Voie  Code_postal               Commune  \
# 0      NaN          NaN  ENTRE LES CHEMINS       1250.0  BOHAS-MEYRIAT-RIGNAT
# ...

# %%
df.tail()
# Out:
#           Unnamed: 0  No_disposition Date_mutation Nature_mutation  \
# 14880468    14880468               1    2019-05-12           Vente
# 14880469    14880469               1    2019-05-12           Vente
# 14880470    14880470               1    2019-10-10    Adjudication
# 14880471    14880471               1    2019-12-30           Vente
# 14880472    14880472               1    2019-12-30           Vente
#
#           Valeur_fonciere  No_voie Type_de_voie           Voie  Code_postal  \
# 14880468       17521000.0     32.0         QUAI     DE BETHUNE      75004.0
# 14880469       17521000.0     32.0         QUAI     DE BETHUNE      75004.0
# 14880470         610000.0     12.0          RUE   BEAUTREILLIS      75004.0
# 14880471        1400000.0     24.0          RUE  SAINT SAUVEUR      75002.0
# 14880472        1400000.0     24.0          RUE  SAINT SAUVEUR      75002.0
#
#            Commune  ... 5eme_lot Surface_Carrez_du_5eme_lot  Nombre_de_lots  \
# ...

# %%
print(df.columns)
print(df.index[5000000])
print(df['Unnamed: 0'][5000000])
# Out:
# Index(['Unnamed: 0', 'No_disposition', 'Date_mutation', 'Nature_mutation',
#        'Valeur_fonciere', 'No_voie', 'Type_de_voie', 'Voie', 'Code_postal',
#        'Commune', 'Code_departement', '1er_lot', 'Surface_Carrez_du_1er_lot',
#        '2eme_lot', 'Surface_Carrez_du_2eme_lot', '3eme_lot',
#        'Surface_Carrez_du_3eme_lot', '4eme_lot', 'Surface_Carrez_du_4eme_lot',
#        '5eme_lot', 'Surface_Carrez_du_5eme_lot', 'Nombre_de_lots',
#        'Code_type_local', 'Type_local', 'Surface_reelle_bati',
#        'Nombre_pieces_principales', 'Nature_culture',
#        'Nature_culture_speciale', 'Surface_terrain'],
#       dtype='object')
# 5000000
# 5000000

# %%
i = 0
while df.index[i] == df['Unnamed: 0'][i]:
    i += 1
print(i)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in __getitem__(self, key)
#     694             try:
# --> 695                 return self._range[new_key]
#     696             except IndexError:
#
# IndexError: range object index out of range
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-ea5fecadeb28> in <module>
#       1 i = 0
# ----> 2 while df.index[i] == df['Unnamed: 0'][i]:
#       3     i += 1
#       4 print(i)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in __getitem__(self, key)
#     696             except IndexError:
#     697                 raise IndexError(
# --> 698                     f"index {key} is out of bounds for axis 0 with size {len(self)}"
# ...
